# %%
# !pip install transformers[torch]
# Out:
# Requirement already satisfied: transformers[torch] in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.19.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.4.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (4.66.1)
# Requirement already satisfied: torch!=1.12.0,>=1.10 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2.1.0+cu118)
# Collecting accelerate>=0.20.3 (from transformers[torch])
#   Downloading accelerate-0.24.1-py3-none-any.whl (261 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.4/261.4 kB 4.4 MB/s eta 0:00:00
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.20.3->transformers[torch]) (5.9.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers[torch]) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers[torch]) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.10->transformers[torch]) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.10->transformers[torch]) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.10->transformers[torch]) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.10->transformers[torch]) (2.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch!=1.12.0,>=1.10->transformers[torch]) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch!=1.12.0,>=1.10->transformers[torch]) (1.3.0)
# Installing collected packages: accelerate
# Successfully installed accelerate-0.24.1

# %%
# !pip install datasets transformers[sentencepiece]
# !pip install sentencepiece
# Out:
# Collecting datasets
#   Downloading datasets-2.15.0-py3-none-any.whl (521 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.2/521.2 kB 5.1 MB/s eta 0:00:00
# Requirement already satisfied: transformers[sentencepiece] in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.23.5)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (9.0.0)
# Collecting pyarrow-hotfix (from datasets)
#   Downloading pyarrow_hotfix-0.5-py3-none-any.whl (7.8 kB)
# Collecting dill<0.3.8,>=0.3.0 (from datasets)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 14.4 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.4.1)
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 16.5 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.8.6)
# Requirement already satisfied: huggingface-hub>=0.18.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.19.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (3.13.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (2023.6.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (0.4.0)
# Collecting sentencepiece!=0.1.92,>=0.1.91 (from transformers[sentencepiece])
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 41.6 MB/s eta 0:00:00
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (3.20.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (3.3.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.18.0->datasets) (4.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2023.7.22)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Installing collected packages: sentencepiece, pyarrow-hotfix, dill, multiprocess, datasets
# Successfully installed datasets-2.15.0 dill-0.3.7 multiprocess-0.70.15 pyarrow-hotfix-0.5 sentencepiece-0.1.99
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (0.1.99)

# %%
import os
import re
import pickle
import string
import unicodedata
from random import randint

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from nltk.corpus import stopwords
from wordcloud import STOPWORDS, WordCloud

from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras import Input, Model
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import LSTM, Bidirectional, Dense, Embedding, TimeDistributed

# %%
# !pip install -q contractions==0.0.48

# %%
from contractions import contractions_dict

for key, value in list(contractions_dict.items())[:10]:
    print(f'{key} == {value}')
# Out:
# I'm == I am
# I'm'a == I am about to
# I'm'o == I am going to
# I've == I have
# I'll == I will
# I'll've == I will have
# I'd == I would
# I'd've == I would have
# Whatcha == What are you
# amn't == am not

# %%
# Using TPU

# detect and init the TPU
tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
tf.config.experimental_connect_to_cluster(tpu)
tf.tpu.experimental.initialize_tpu_system(tpu)

# instantiate a distribution strategy
tpu_strategy = tf.distribute.experimental.TPUStrategy(tpu)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-4e582115bd0f> in <cell line: 4>()
#       2
#       3 # detect and init the TPU
# ----> 4 tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
#       5 tf.config.experimental_connect_to_cluster(tpu)
#       6 tf.tpu.experimental.initialize_tpu_system(tpu)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/distribute/cluster_resolver/tpu/tpu_cluster_resolver.py in __init__(self, tpu, zone, project, job_name, coordinator_name, coordinator_address, credentials, service, discovery_url)
#     233     if tpu != 'local':
#     234       # Default Cloud environment
# --> 235       self._cloud_tpu_client = client.Client(
#     236           tpu=tpu,
#     237           zone=zone,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/tpu/client/client.py in __init__(self, tpu, zone, project, credentials, service, discovery_url)
#     157         zone = zone or tpu_node_config.get('zone')
#     158       else:
# --> 159         raise ValueError('Please provide a TPU Name to connect to.')
#     160
#     161     self._tpu = _as_text(tpu)
#
# ValueError: Please provide a TPU Name to connect to.

# %%
filename1 = 'news_summary.csv'
filename2 = 'news_summary_more.csv'

df1 = pd.read_csv(filename1, encoding='iso-8859-1').reset_index(drop=True)
df2 = pd.read_csv(filename2, encoding='iso-8859-1').reset_index(drop=True)

# %%
df1.sample(5)
# Out:
#              author                   date  \
# 2065  Vaibhav Gupta  14 Dec 2016,Wednesday
# 1272     Ankur Vyas  08 Feb 2017,Wednesday
# 3266  Sumedha Sehra     22 May 2017,Monday
# 4143    Daisy Mowke  22 Mar 2017,Wednesday
# 425   Radhika Chugh   27 Jul 2017,Thursday
#
#                                               headlines  \
# 2065  Top Lashkar-e-Taiba commander killed by armed ...
# 1272     Panneerselvam acting at DMK's behest: Sasikala
# 3266          India a victim of terrorism: Donald Trump
# 4143  Kangana to start Rani Laxmibai biopic on b'day...
# 425   Court convicts school authorities for traumati...
#
#                                               read_more  \
# 2065  http://indiatoday.intoday.in/story/sopore-enco...
# 1272  http://indiatoday.intoday.in/story/sasikala-na...
# 3266  http://indiatoday.intoday.in/story/india-a-vic...
# 4143  http://indiatoday.intoday.in/story/kangana-ran...
# 425   http://www.hindustantimes.com/delhi-news/princ...
#
#                                                    text  \
# 2065  Indian security forces on Wednesday killed top...
# 1272  Asserting that there was no rift within the pa...
# 3266  US President Donald Trump said in his speech i...
# 4143  According to reports, actress Kangana Ranaut w...
# 425   A Delhi court on Wednesday awarded a school pr...
#
#                                                   ctext
# 2065  The 6-hour-long encounter in Jammu and Kashmir...
# 1272  AIADMK general secretary Sasikala Natarajan to...
# 3266  United States President Donald Trump, during h...
# 4143  Biopics seems to be the thing with Bollywood. ...
# 425   In an unprecedented verdict, a Delhi court on ...

# %%
df2.sample(5)
# Out:
#                                                headlines  \
# 20839  Signing nuclear deal may have been a mistake: ...
# 4565   IIT Roorkee makes system to alert people a min...
# 32726  No delay in informing about Ghosh's resignatio...
# 23964  Prakash Jha to direct a biopic on a Bihar math...
# 89971  Pak pilot sleeps on flight, leaves control wit...
#
#                                                     text
# 20839  Iranian Foreign Minister Javad Zarif has said ...
# 4565   Scientists at IIT Roorkee have claimed to deve...
# 32726  India's largest airline IndiGo on Thursday sai...
# 23964  Prakash Jha is set to direct a biopic on Bihar...
# 89971  A senior Pakistan International Airlines (PIA)...

# %%
df1_columns = df1.columns.tolist()
df1_columns.remove('headlines')
df1_columns.remove('text')
df1.drop(df1_columns, axis='columns', inplace=True)

df = pd.concat([df1, df2], axis='rows')
del df1, df2

# Shuffling the df
df = df.sample(frac=1).reset_index(drop=True)

print(f'Dataset size: {len(df)}')
df.sample(5)
# Out:
# Dataset size: 102915
#                                                headlines  \
# 62787  Astronomers narrow down on source of mysteriou...
# 5556   Flipkart's Snapdeal buyout said to benefit Tig...
# 61322  K'taka govt prohibits protest by waste contrac...
# 13159  Banks didn't implement demonetisation properly...
# 22906       Mumbai Indians ease past Sunrisers Hyderabad
#
#                                                     text
# 62787  Astronomers have found evidence that repeated ...
# 5556   Flipkart's reported $1 billion buyout of Snapd...
# 61322  The Karnataka government has invoked the Essen...
# 13159  Bihar CM Nitish Kumar on Sunday blamed the ban...
# 22906  Mumbai Indians eased to a 4-wicket win over de...

# %%
def expand_contractions(text, contraction_map=contractions_dict):
    # Using regex for getting all contracted words
    contractions_keys = '|'.join(contraction_map.keys())
    contractions_pattern = re.compile(f'({contractions_keys})', flags=re.DOTALL)

    def expand_match(contraction):
        # Getting entire matched sub-string
        match = contraction.group(0)
        expanded_contraction = contraction_map.get(match)
        if not expand_contractions:
            print(match)
            return match
        return expanded_contraction

    expanded_text = contractions_pattern.sub(expand_match, text)
    expanded_text = re.sub("'", "", expanded_text)
    return expanded_text


# Converting to lowercase
df.text = df.text.apply(str.lower)
df.headlines = df.headlines.apply(str.lower)
df.headlines = df.headlines.apply(expand_contractions)
df.text = df.text.apply(expand_contractions)
df.sample(5)

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Remove puncuation from word
def rm_punc_from_word(word):
    clean_alphabet_list = [
        alphabet for alphabet in word if alphabet not in string.punctuation
    ]
    return ''.join(clean_alphabet_list)

# Remove puncuation from text
def rm_punc_from_text(text):
    clean_word_list = [rm_punc_from_word(word) for word in text]
    return ''.join(clean_word_list)

# Remove numbers from text
def rm_number_from_text(text):
    text = re.sub('[0-9]+', '', text)
    return ' '.join(text.split())  # to rm `extra` white space

# Remove stopwords from text
def rm_stopwords_from_text(text):
    _stopwords = stopwords.words('english')
    text = text.split()
    word_list = [word for word in text if word not in _stopwords]
    return ' '.join(word_list)

# Cleaning text
def clean_text(text):
    text = text.lower()
    text = rm_punc_from_text(text)
    text = rm_number_from_text(text)
    text = rm_stopwords_from_text(text)

    # there are hyphen(–) in many titles, so replacing it with empty str
    # this hyphen(–) is different from normal hyphen(-)
    text = re.sub('–', '', text)
    text = ' '.join(text.split())  # removing `extra` white spaces

    # Removing unnecessary characters from text
    text = re.sub("(\\t)", ' ', str(text)).lower()
    text = re.sub("(\\r)", ' ', str(text)).lower()
    text = re.sub("(\\n)", ' ', str(text)).lower()

    # remove accented chars ('Sómě Áccěntěd těxt' => 'Some Accented text')
    text = unicodedata.normalize('NFKD', text).encode('ascii', 'ignore').decode(
        'utf-8', 'ignore'
    )

    text = re.sub("(__+)", ' ', str(text)).lower()
    text = re.sub("(--+)", ' ', str(text)).lower()
    text = re.sub("(~~+)", ' ', str(text)).lower()
    text = re.sub("(\+\++)", ' ', str(text)).lower()
    text = re.sub("(\.\.+)", ' ', str(text)).lower()

    text = re.sub(r"[<>()|&©ø\[\]\'\",;?~*!]", ' ', str(text)).lower()

    text = re.sub("(mailto:)", ' ', str(text)).lower()
    text = re.sub(r"(\\x9\d)", ' ', str(text)).lower()
    text = re.sub("([iI][nN][cC]\d+)", 'INC_NUM', str(text)).lower()
    text = re.sub("([cC][mM]\d+)|([cC][hH][gG]\d+)", 'CM_NUM',
                  str(text)).lower()

    text = re.sub("(\.\s+)", ' ', str(text)).lower()
    text = re.sub("(\-\s+)", ' ', str(text)).lower()
    text = re.sub("(\:\s+)", ' ', str(text)).lower()
    text = re.sub("(\s+.\s+)", ' ', str(text)).lower()

    try:
        url = re.search(r'((https*:\/*)([^\/\s]+))(.[^\s]+)', str(text))
        repl_url = url.group(3)
        text = re.sub(r'((https*:\/*)([^\/\s]+))(.[^\s]+)', repl_url, str(text))
    except Exception as e:
        pass

    text = re.sub("(\s+)", ' ', str(text)).lower()
    text = re.sub("(\s+.\s+)", ' ', str(text)).lower()

    return text

df.text = df.text.apply(clean_text)
df.headlines = df.headlines.apply(clean_text)
df.sample(5)
# Out:
#                                                headlines  \
# 17678    making big west never sethemed worth dharmendra
# 4602   congress leaders meet ec dthemand action amit ...
# 94404     woman petitioned nikah halala receives threats
# 90871           aaa1 lakh robot clap hands dthemand made
# 94616            us police offer test meth deadly gluten
#
#                                                     text
# 17678  veteran actor dharmendra said though actors tr...
# 4602   congress leaders approached election commissio...
# 94404  delhibased woman petitioned nikah halala suprt...
# 90871  japanese designer masato takahashi developed r...
# 94616  california police officers offered test meth d...

# %%
# saving the cleaned data
df.to_csv('preprocessed_data.csv')

# %%
df.headlines = df.headlines.apply(lambda x: f'_START_ {x} _END_')
start_token = 'sostok'
end_token = 'eostok'
df.headlines = df.headlines.apply(lambda x: f'{start_token} {x} {end_token}')
df.sample(5)
# Out:
#                                                headlines  \
# 58717  sostok _START_ aamir khan unveils first look p...
# 98062  sostok _START_ gujarat assthembly increases ml...
# 94008  sostok _START_ rbi prove credibility dthemonet...
# 80217  sostok _START_ sharjahbound plane makes themer...
# 79001  sostok _START_ amu follows taliban ideology bj...
#
#                                                     text
# 58717  actor aamir khan today unveiled first look pos...
# 98062  mthember gujarat assthembly wednesday passed b...
# 94008  vice president venkaiah naidu monday urged res...
# 80217  sharjahbound air arabia plane made themergency...
# 79001  news reports claimed posters showing map india...

# %%
text_count = [len(sentence.split()) for sentence in df.text]
headlines_count = [len(sentence.split()) for sentence in df.headlines]

pd.DataFrame({'text': text_count, 'headlines': headlines_count}).hist(bins=100, figsize=(16, 4), range=[0, 50])
plt.show()

# %%
# To check how many rows in a column has length (of the text) <= limit
def get_word_percent(column, limit):
    count = 0
    for sentence in column:
        if len(sentence.split()) <= limit:
            count += 1

    return round(count / len(column), 2)


# Check how many % of headlines have 0-13 words
print(get_word_percent(df.headlines, 14))

# Check how many % of summary have 0-42 words
print(get_word_percent(df.text, 43))
# Out:
# 1.0
# 0.99

# %%
max_text_len = 43
max_summary_len = 14
# select the summary and text between their defined max lens respectively
def trim_text_and_summary(df, max_text_len, max_summary_len):
    cleaned_text = np.array(df['text'])
    cleaned_summary = np.array(df['headlines'])

    short_text = []
    short_summary = []

    for i in range(len(cleaned_text)):
        if len(cleaned_text[i].split()) <= max_text_len and len(
            cleaned_summary[i].split()
        ) <= max_summary_len:
            short_text.append(cleaned_text[i])
            short_summary.append(cleaned_summary[i])

    df = pd.DataFrame({'text': short_text, 'summary': short_summary})
    return df


df = trim_text_and_summary(df, max_text_len, max_summary_len)
print(f'Dataset size: {len(df)}')
df.sample(5)
# Out:
# Dataset size: 102112
#                                                     text  \
# 91380  government ded pay special protection group pe...
# 26499  indians taken snapchat ceo evan spiegels fianc...
# 10402  icici bank ceo chanda kochhars brotherinlaw ra...
# 91513  total bills listed introduction parliaments mo...
# 77961  russian social media network vkontakte allowed...
#
#                                                  summary
# 91380  sostok _START_ spg officers get highest dress ...
# 26499  sostok _START_ indians troll snapchat ceofs fi...
# 10402  sostok _START_ chanda kochhars brotherinlaw de...
# 91513  sostok _START_ bills listed introduction monso...
# 77961  sostok _START_ russian social network lets use...

# %%
# rare word analysis
def get_rare_word_percent(tokenizer, threshold):
    # threshold: if the word's occurrence is less than this then it's rare word

    count = 0
    total_count = 0
    frequency = 0
    total_frequency = 0

    for key, value in tokenizer.word_counts.items():
        total_count += 1
        total_frequency += value
        if value < threshold:
            count += 1
            frequency += value

    return {
        'percent': round((count / total_count) * 100, 2),
        'total_coverage': round(frequency / total_frequency * 100, 2),
        'count': count,
        'total_count': total_count
    }

# %%
# Splitting the training and validation sets
x_train, x_val, y_train, y_val = train_test_split(
    np.array(df['text']),
    np.array(df['summary']),
    test_size=0.1,
    random_state=1,
    shuffle=True
)

# %%
x_train[0]
# Out:
# 'praising son ranbir kapoors girlfriend alia bhatt rishi kapoor said admire taking challenging roles like highway raazi isdifficult tender age carry film shoulders actor added rishi said alia lucky course talent'

# %%
x_tokenizer = Tokenizer()
x_tokenizer.fit_on_texts(list(x_train))

x_tokens_data = get_rare_word_percent(x_tokenizer, 4)
print(x_tokens_data)
# Out:
# {'percent': 65.26, 'total_coverage': 2.92, 'count': 65806, 'total_count': 100835}

# %%
# save tokenizer
with open('x_tokenizer', 'wb') as f:
    pickle.dump(x_tokenizer, f, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# one-hot-encoding
x_train_sequence = x_tokenizer.texts_to_sequences(x_train)
x_val_sequence = x_tokenizer.texts_to_sequences(x_val)

# padding upto max_text_len
x_train_padded = pad_sequences(x_train_sequence, maxlen=max_text_len, padding='post')
x_val_padded = pad_sequences(x_val_sequence, maxlen=max_text_len, padding='post')

# if you're not using num_words parameter in Tokenizer then use this
x_vocab_size = len(x_tokenizer.word_index) + 1

print(x_vocab_size)
# Out:
# 100836

# %%
y_tokenizer = Tokenizer()
y_tokenizer.fit_on_texts(list(y_train))

y_tokens_data = get_rare_word_percent(y_tokenizer, 6)
print(y_tokens_data)
# Out:
# {'percent': 69.2, 'total_coverage': 4.74, 'count': 26216, 'total_count': 37885}

# %%
# save tokenizer
with open('y_tokenizer', 'wb') as f:
    pickle.dump(y_tokenizer, f, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# one-hot-encoding
y_train_sequence = y_tokenizer.texts_to_sequences(y_train)
y_val_sequence = y_tokenizer.texts_to_sequences(y_val)

# padding upto max_summary_len
y_train_padded = pad_sequences(y_train_sequence, maxlen=max_summary_len, padding='post')
y_val_padded = pad_sequences(y_val_sequence, maxlen=max_summary_len, padding='post')

# if you're not using num_words parameter in Tokenizer then use this
y_vocab_size = len(y_tokenizer.word_index) + 1

# else use this
# y_vocab_size = y_tokenizer.num_words + 1

print(y_vocab_size)
# Out:
# 37886

# %%
# removing summary which only has sostok & eostok
def remove_indexes(summary_array):
    remove_indexes = []
    for i in range(len(summary_array)):
        count = 0
        for j in summary_array[i]:
            if j != 0:
                count += 1
        if count == 2:
            remove_indexes.append(i)
    return remove_indexes


remove_train_indexes = remove_indexes(y_train_padded)
remove_val_indexes = remove_indexes(y_val_padded)

y_train_padded = np.delete(y_train_padded, remove_train_indexes, axis=0)
x_train_padded = np.delete(x_train_padded, remove_train_indexes, axis=0)

y_val_padded = np.delete(y_val_padded, remove_val_indexes, axis=0)
x_val_padded = np.delete(x_val_padded, remove_val_indexes, axis=0)

# %%
latent_dim = 240
embedding_dim = 300
num_epochs = 50

# %%
def get_embedding_matrix(tokenizer, embedding_dim, vocab_size=None):
    word_index = tokenizer.word_index
    voc = list(word_index.keys())

    path_to_glove_file = 'glove.6B.300d.txt'

    embeddings_index = {}
    with open(path_to_glove_file) as f:
        for line in f:
            word, coefs = line.split(maxsplit=1)
            coefs = np.fromstring(coefs, "f", sep=" ")
            embeddings_index[word] = coefs

    print("Found %s word vectors." % len(embeddings_index))

    num_tokens = len(voc) + 2 if not vocab_size else vocab_size
    hits = 0
    misses = 0

    # Prepare embedding matrix
    embedding_matrix = np.zeros((num_tokens, embedding_dim))
    for word, i in word_index.items():
        embedding_vector = embeddings_index.get(word)
        if embedding_vector is not None:
            # Words not found in embedding index will be all-zeros.
            # This includes the representation for "padding" and "OOV"
            embedding_matrix[i] = embedding_vector
            hits += 1
        else:
            misses += 1
    print("Converted %d words (%d misses)" % (hits, misses))

    return embedding_matrix


x_embedding_matrix = get_embedding_matrix(x_tokenizer, embedding_dim, x_vocab_size)
y_embedding_matrix = get_embedding_matrix(y_tokenizer, embedding_dim, y_vocab_size)
# Out:
# Found 8882 word vectors.
# Converted 7880 words (92955 misses)
# Found 8882 word vectors.
# Converted 7194 words (30691 misses)

# %%
def build_hybrid_seq2seq_model(
    embedding_dim, latent_dim, max_text_len,
    x_vocab_size, y_vocab_size,
    x_embedding_matrix, y_embedding_matrix
):
    # instantiating the model in the strategy scope creates the model on the TPU

        #Encoder
        encoder_input = Input(shape=(max_text_len, ))
        # encoder embedding layer
        encoder_embedding = Embedding(
            x_vocab_size,
            embedding_dim,
            embeddings_initializer=tf.keras.initializers.Constant(x_embedding_matrix),
            trainable=False,
            name='encoder_embedding'
        )(encoder_input)

        # encoder lstm1
        encoder_bi_lstm1 = Bidirectional(
            LSTM(
                latent_dim,
                return_sequences=True,
                return_state=True,
                dropout=0.4,
                recurrent_dropout=0.4,
                name='encoder_lstm_1'
            ),
            name='encoder_bidirectional_lstm_1'
        )
        encoder_output1, forward_h1, forward_c1, backward_h1, backward_c1 = encoder_bi_lstm1(
            encoder_embedding
        )
        encoder_bi_lstm1_output = [
            encoder_output1, forward_h1, forward_c1, backward_h1, backward_c1
        ]

        # encoder lstm 2
        encoder_bi_lstm2 = Bidirectional(
            LSTM(
                latent_dim,
                return_sequences=True,
                return_state=True,
                dropout=0.4,
                recurrent_dropout=0.4,
                name='encoder_lstm_2'
            ),
            name='encoder_bidirectional_lstm_2'
        )
        encoder_output2, forward_h2, forward_c2, backward_h2, backward_c2 = encoder_bi_lstm2(
            encoder_output1
        )
        encoder_bi_lstm2_output = [
            encoder_output2, forward_h2, forward_c2, backward_h2, backward_c2
        ]

        # encoder lstm 3
        encoder_bi_lstm = Bidirectional(
            LSTM(
                latent_dim,
                return_sequences=True,
                return_state=True,
                dropout=0.4,
                recurrent_dropout=0.4,
                name='encoder_lstm_3'
            ),
            name='encoder_bidirectional_lstm_3'
        )
        encoder_output, *encoder_final_states = encoder_bi_lstm(encoder_output2)

        #Decoder

        decoder_input = Input(shape=(None, ))

        # decoder embedding layer
        decoder_embedding_layer = Embedding(
            y_vocab_size,
            embedding_dim,
            embeddings_initializer=tf.keras.initializers.Constant(y_embedding_matrix),
            trainable=False,
            name='decoder_embedding'
        )
        decoder_embedding = decoder_embedding_layer(decoder_input)

        decoder_lstm = LSTM(
            latent_dim,
            return_sequences=True,
            return_state=True,
            dropout=0.4,
            recurrent_dropout=0.2,
            name='decoder_lstm_1'
        )
        decoder_output, *decoder_final_states = decoder_lstm(
            decoder_embedding, initial_state=encoder_final_states[:2]
        )  # taking only the forward states

        # dense layer
        decoder_dense = TimeDistributed(
            Dense(y_vocab_size, activation='softmax')
        )
        decoder_output = decoder_dense(decoder_output)

        #Model
        model = Model([encoder_input, decoder_input], decoder_output, name='seq2seq_model_with_bidirectional_lstm')
        model.summary()

        optimizer = tf.keras.optimizers.RMSprop(learning_rate=0.001)
        model.compile(
            optimizer=optimizer,
            loss='sparse_categorical_crossentropy',
            metrics=['accuracy']
        )

        return {
            'model': model,
            'inputs': {
                'encoder': encoder_input,
                'decoder': decoder_input
            },
            'outputs': {
                'encoder': encoder_output,
                'decoder': decoder_output
            },
            'states': {
                'encoder': encoder_final_states,
                'decoder': decoder_final_states
            },
            'layers': {
                'decoder': {
                    'embedding': decoder_embedding_layer,
                    'last_decoder_lstm': decoder_lstm,
                    'dense': decoder_dense
                }
            }
        }

# %%
seq2seq = build_hybrid_seq2seq_model(
    embedding_dim, latent_dim, max_text_len,
    x_vocab_size, y_vocab_size,
    x_embedding_matrix, y_embedding_matrix
)
# Out:
# Model: "seq2seq_model_with_bidirectional_lstm"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 43)]                 0         []
#
#  encoder_embedding (Embeddi  (None, 43, 300)              3025080   ['input_1[0][0]']
#  ng)                                                      0
#
#  encoder_bidirectional_lstm  [(None, 43, 480),            1038720   ['encoder_embedding[0][0]']
#  _1 (Bidirectional)           (None, 240),
#                               (None, 240),
#                               (None, 240),
#                               (None, 240)]
#
#  input_2 (InputLayer)        [(None, None)]               0         []
#
#  encoder_bidirectional_lstm  [(None, 43, 480),            1384320   ['encoder_bidirectional_lstm_1
#  _2 (Bidirectional)           (None, 240),                          [0][0]']
#                               (None, 240),
#                               (None, 240),
#                               (None, 240)]
#
#  decoder_embedding (Embeddi  (None, None, 300)            1136580   ['input_2[0][0]']
#  ng)                                                      0
#
#  encoder_bidirectional_lstm  [(None, 43, 480),            1384320   ['encoder_bidirectional_lstm_2
#  _3 (Bidirectional)           (None, 240),                          [0][0]']
#                               (None, 240),
#                               (None, 240),
#                               (None, 240)]
#
#  decoder_lstm_1 (LSTM)       [(None, None, 240),          519360    ['decoder_embedding[0][0]',
#                               (None, 240),                           'encoder_bidirectional_lstm_3
#                               (None, 240)]                          [0][1]',
#                                                                      'encoder_bidirectional_lstm_3
#                                                                     [0][2]']
#
#  time_distributed (TimeDist  (None, None, 37886)          9130526   ['decoder_lstm_1[0][0]']
#  ributed)
#
# ==================================================================================================
# Total params: 55073846 (210.09 MB)
# Trainable params: 13457246 (51.34 MB)
# Non-trainable params: 41616600 (158.75 MB)
# __________________________________________________________________________________________________

# %%
model = seq2seq['model']

encoder_input = seq2seq['inputs']['encoder']
decoder_input = seq2seq['inputs']['decoder']

encoder_output = seq2seq['outputs']['encoder']
decoder_output = seq2seq['outputs']['decoder']

encoder_final_states = seq2seq['states']['encoder']
decoder_final_states = seq2seq['states']['decoder']

decoder_embedding_layer = seq2seq['layers']['decoder']['embedding']
last_decoder_lstm = seq2seq['layers']['decoder']['last_decoder_lstm']
decoder_dense = seq2seq['layers']['decoder']['dense']

# %%
model.layers[-2].input
# Out:
# [<KerasTensor: shape=(None, None, 300) dtype=float32 (created by layer 'decoder_embedding')>,
#  <KerasTensor: shape=(None, 240) dtype=float32 (created by layer 'encoder_bidirectional_lstm_3')>,
#  <KerasTensor: shape=(None, 240) dtype=float32 (created by layer 'encoder_bidirectional_lstm_3')>]

# %%
callbacks = [
    EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=2),
    ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=2, min_lr=0.000001, verbose=1),
]

# %%
history = model.fit(
    [x_train_padded, y_train_padded[:, :-1]],
    y_train_padded.reshape(y_train_padded.shape[0], y_train_padded.shape[1], 1)[:, 1:],
    epochs=num_epochs,
    batch_size=128 ,
    callbacks=callbacks,
    validation_data=(
        [x_val_padded, y_val_padded[:, :-1]],
        y_val_padded.reshape(y_val_padded.shape[0], y_val_padded.shape[1], 1)[:, 1:]
    )
)
# Out:
# Epoch 1/50
# WARNING:tensorflow:Gradients do not exist for variables ['encoder_bidirectional_lstm_3/backward_encoder_lstm_3/lstm_cell/kernel:0', 'encoder_bidirectional_lstm_3/backward_encoder_lstm_3/lstm_cell/recurrent_kernel:0', 'encoder_bidirectional_lstm_3/backward_encoder_lstm_3/lstm_cell/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['encoder_bidirectional_lstm_3/backward_encoder_lstm_3/lstm_cell/kernel:0', 'encoder_bidirectional_lstm_3/backward_encoder_lstm_3/lstm_cell/recurrent_kernel:0', 'encoder_bidirectional_lstm_3/backward_encoder_lstm_3/lstm_cell/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['encoder_bidirectional_lstm_3/backward_encoder_lstm_3/lstm_cell/kernel:0', 'encoder_bidirectional_lstm_3/backward_encoder_lstm_3/lstm_cell/recurrent_kernel:0', 'encoder_bidirectional_lstm_3/backward_encoder_lstm_3/lstm_cell/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['encoder_bidirectional_lstm_3/backward_encoder_lstm_3/lstm_cell/kernel:0', 'encoder_bidirectional_lstm_3/backward_encoder_lstm_3/lstm_cell/recurrent_kernel:0', 'encoder_bidirectional_lstm_3/backward_encoder_lstm_3/lstm_cell/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
#  72/718 [==>...........................] - ETA: 1:28:09 - loss: 6.5982 - accuracy: 0.3023
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-48-d95f985a4986> in <cell line: 1>()
# ----> 1 history = model.fit(
#       2     [x_train_padded, y_train_padded[:, :-1]],
#       3     y_train_padded.reshape(y_train_padded.shape[0], y_train_padded.shape[1], 1)[:, 1:],
#       4     epochs=num_epochs,
#       5     batch_size=128 ,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1781                         ):
#    1782                             callbacks.on_train_batch_begin(step)
# -> 1783                             tmp_logs = self.train_function(iterator)
#    1784                             if data_handler.should_sync:
#    1785                                 context.async_wait()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     829
#     830       with OptionalXlaContext(self._jit_compile):
# --> 831         result = self._call(*args, **kwds)
#     832
#     833       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     865       # In this case we have created variables on the first call, so we run the
#     866       # defunned version which is guaranteed to never create variables.
# --> 867       return tracing_compilation.call_function(
#     868           args, kwds, self._no_variable_creation_config
#     869       )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     137   bound_args = function.function_type.bind(*args, **kwargs)
#     138   flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139   return function._call_flat(  # pylint: disable=protected-access
#     140       flat_inputs, captured_inputs=function.captured_inputs
#     141   )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py in _call_flat(self, tensor_inputs, captured_inputs)
#    1262         and executing_eagerly):
#    1263       # No tape is watching; skip to running the function.
# -> 1264       return self._inference_function.flat_call(args)
#    1265     forward_backward = self._select_forward_and_backward_functions(
#    1266         args,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in flat_call(self, args)
#     215   def flat_call(self, args: Sequence[core.Tensor]) -> Any:
#     216     """Calls with tensor inputs and returns the structured output."""
# --> 217     flat_outputs = self(*args)
#     218     return self.function_type.pack_output(flat_outputs)
#     219
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in __call__(self, *args)
#     250         with record.stop_recording():
#     251           if self._bound_context.executing_eagerly():
# --> 252             outputs = self._bound_context.call_function(
#     253                 self.name,
#     254                 list(args),
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1477     cancellation_context = cancellation.context()
#    1478     if cancellation_context is None:
# -> 1479       outputs = execute.execute(
#    1480           name.decode("utf-8"),
#    1481           num_outputs=num_outputs,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58         for t in inputs
#      59     ]
# ---> 60     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      61                                         inputs, attrs, num_outputs)
#      62   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
# Next, let’s build the dictionary to convert the index to word for target and source vocabulary:
reverse_target_word_index = y_tokenizer.index_word
reverse_source_word_index = x_tokenizer.index_word
target_word_index = y_tokenizer.word_index

# %%
def build_hybrid_seq2seq_model_inference(
    max_text_len, latent_dim, encoder_input, encoder_output,
    encoder_final_states, decoder_input, decoder_output,
    decoder_embedding_layer, decoder_dense, last_decoder_bi_lstm
):

    # Encode the input sequence to get the feature vector
    encoder_model = Model(
        inputs=encoder_input, outputs=[encoder_output] + encoder_final_states
    )

    # Decoder setup
    # Below tensors will hold the states of the previous time step
    decoder_state_forward_input_h = Input(shape=(latent_dim, ))
    decoder_state_forward_input_c = Input(shape=(latent_dim, ))
    # decoder_state_backward_input_h = Input(shape=(latent_dim, ))
    # decoder_state_backward_input_c = Input(shape=(latent_dim, ))

    # Create the hidden input layer with twice the latent dimension,
    # since we are using bi - directional LSTM's we will get
    # two hidden states and two cell states
    decoder_hidden_state_input = Input(shape=(max_text_len, latent_dim * 2))

    decoder_initial_state = [
        decoder_state_forward_input_h, decoder_state_forward_input_c,
        #decoder_state_backward_input_h, decoder_state_backward_input_c
    ]

    # Get the embeddings of the decoder sequence
    decoder_embedding = decoder_embedding_layer(decoder_input)

    # To predict the next word in the sequence, set the initial
    # states to the states from the previous time step
    decoder_output, *decoder_states = last_decoder_bi_lstm(
        decoder_embedding, initial_state=decoder_initial_state
    )

    # A dense softmax layer to generate prob dist. over the target vocabulary
    decoder_output = decoder_dense(decoder_output)

    # Final decoder model
    decoder_model = Model(
        [decoder_input] + [decoder_hidden_state_input] + decoder_initial_state,
        [decoder_output] + decoder_states
    )

    return (encoder_model, decoder_model)

# %%
encoder_model, decoder_model = build_hybrid_seq2seq_model_inference(
    max_text_len, latent_dim, encoder_input, encoder_output,
    encoder_final_states, decoder_input, decoder_output,
    decoder_embedding_layer, decoder_dense, last_decoder_lstm
)

# %%
def decode_sequence_hybrid_seq2seq_model(
    input_sequence, encoder_model, decoder_model
):
    # Encode the input as state vectors.
    e_out, *state_values = encoder_model.predict(input_sequence)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1, 1))

    # Populate the first word of target sequence with the start word.
    target_seq[0, 0] = target_word_index[start_token]

    stop_condition = False
    decoded_sentence = ''

    while not stop_condition:
        output_tokens, *decoder_states = decoder_model.predict(
            [target_seq] + [e_out] + state_values[:2]
        )

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :]) # Greedy Search
        sampled_token = reverse_target_word_index[sampled_token_index + 1]

        if sampled_token != end_token:
            decoded_sentence += ' ' + sampled_token

        # Exit condition: either hit max length or find stop word.
        if (sampled_token == end_token) or (len(decoded_sentence.split()) >= (max_summary_len - 1)):
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1, 1))
        target_seq[0, 0] = sampled_token_index

        # Update internal states
        state_values = decoder_states

    return decoded_sentence

# %%
def seq2summary(input_sequence):
    new_string = ''
    for i in input_sequence:
        if (
            (i != 0 and i != target_word_index[start_token]) and
            (i != target_word_index[end_token])
        ):
            new_string = new_string + reverse_target_word_index[i] + ' '
    return new_string

# %%
def seq2text(input_sequence):
    new_string = ''
    for i in input_sequence:
        if i != 0:
            new_string = new_string + reverse_source_word_index[i] + ' '
    return new_string

# %%
def predict_text(text, decode_sequence, encoder_model, decoder_model):
    original_text = text
    text = clean_text([text])  # generator
    text_list = original_text.split()

    if len(text_list) <= max_text_len:
        text = expand_contractions(text)
        text = clean_text(text)
        text = f'_START_ {text} _END_'
        text = f'{start_token} {text} {end_token}'

        seq = x_tokenizer.texts_to_sequences([' '.join(text_list)])
        padded = pad_sequences(seq, maxlen=max_text_len, padding='post')
        pred_summary = decode_sequence(
            padded.reshape(1, max_text_len), encoder_model, decoder_model
        )
        return pred_summary
    else:
        pred_summary = ''

        # breaking long texts to individual max_text_len texts and predicting on them
        while len(text_list) % max_text_len == 0:
            text_list.append('')

        lst_i = max_text_len
        for i in range(0, len(text_list), max_text_len):
            _text_list = original_text.split()[i:i + lst_i]
            _text = ' '.join(_text_list)
            _text = ' '.join(
                _text.split()
            )  # to remove spaces that were added to make len(text_list) % max_text_len == 0

            _text = expand_contractions(_text)
            _text = clean_text(_text)  # generator
            _text = f'_START_ {_text} _END_'
            _text = f'{start_token} {_text} {end_token}'
            # print(_text, '\n')

            _seq = x_tokenizer.texts_to_sequences([_text])
            _padded = pad_sequences(_seq, maxlen=max_text_len, padding='post')
            _pred = decode_sequence(
                _padded.reshape(1, max_text_len), encoder_model, decoder_model
            )
            pred_summary += ' ' + ' '.join(_pred.split()[1:-2])
            pred_summary = ' '.join(pred_summary.split())

        return pred_summary

# %%
# Testing on training data
for i in range(0, 15):
    print(f"# {i+1} News: ", seq2text(x_train_padded[i]))
    print("Original summary: ", seq2summary(y_train_padded[i]))
    print(
        "Predicted summary: ",
        decode_sequence_hybrid_seq2seq_model(
            x_train_padded[i].reshape(1, max_text_len), encoder_model,
            decoder_model
        )
    )
    print()

# %%
# Testing on validation data
for i in range(0, 15):
    print(f"# {i+1} News: ", seq2text(x_val_padded[i]))
    print("Original summary: ", seq2summary(y_val_padded[i]))
    print(
        "Predicted summary: ",
        decode_sequence_seq2seq_model_with_just_lstm(
            x_val_padded[i].reshape(1, max_text_len), encoder_model,
            decoder_model
        )
    )
    print()

# %%
# HDF5 format
model.save('model.h5')
encoder_model.save('encoder_model.h5')
decoder_model.save('decoder_model.h5')

# %%
x_train=x_train.tolist()
y_train=y_train.tolist()
x_train[:1000]
# Out:
# ['praising son ranbir kapoors girlfriend alia bhatt rishi kapoor said admire taking challenging roles like highway raazi isdifficult tender age carry film shoulders actor added rishi said alia lucky course talent',
#  'indianorigin mohammed dewji africas youngest billionaire aged returned home safely kidnapped unidentified men way gym tanzania days ago kidnappers abandoned dewji found police dewji hands legs face tied throughout captivity could identify abductors',
#  'richa chadha aditi rao hydari rahul bhat starrer daas dev released today messy cocktail themotions power games wrote hindustan times ht totality film grip said times india toi indian express wrote film enough impact rated ht toi indian express',
#  'tenth edition indian prthemier league saw records broken mumbai indians became first team win three ipl titles going past kolkata knight riders chennai super kings two titles gujarat lions recorded worst ipl collapse lastever match royal challengers bangalore posted lowestever ipl total',
#  'venezuela offered india discount crude oil purchases made using oilbacked venezuelan cryptocurrency petro according mohit kalra ceo indian crypto exchange coinsecure venezuela reportedly entered pact coinsecure sell petro india notably us banned transactions involving petro saying intended bypass us sanctions',
#  'kingfisher launching kfit band tells much much comes beers released video showcases scenarios wherein band used like gift girlfriend boyfriend father son end scientist explains alcosenseaaa technology behind band',
#  'hrithik roshan said priyanka chopra could easily dumb could intimidate depending person situation case transformation intellect driven generous heart make people around comfortable added said priyanka fits situation like chameleon',
#  'three people died jammu rains caused increase levels rivers streams triggered flash floods region yearold man washed away crossing stream friday yearold youth died trying cross river yearold woman died tree fell saturday',
#  'actor shahid kapoor shared picture brother ishaan khattar launch debut film beyond clouds film also first indian film iranian filmmaker majid majidi known directing irans first oscar nominated film children heaven majidi said ishaan wonderful boy extrthemely talented',
#  'government ded sell four air india subsidiaries include regional airline alliance air hotel corporation india owns two hotels delhi srinagar subsidiaries air india engineering services involved maintenance repair overhaul engines air india air transport services passenger cargo handling unit',
#  'reacting team india head coach ravi shastri napping dressing room first day first englandindia test user tweeted coaches also undergo mini yo yo tests tweets read hope arnab goswami doesnaaat get know test cricket still pinnacle right',
#  'parliaments recently concluded budget session productive winter session lok sabha recorded productivity terms scheduled hours budget session witnessed productivity winter session meanwhile rajya sabha nearly five times productive budget session winter session',
#  'mumbais thane get childrens traffic park educate children traffic rules themergency services road safety lane ings zebra crossings road signages park displays dthemonstrations slide shows workshops exhibition street plays explain rules park also cycle training tracks people learn bike ridingaaa officials said',
#  'kannada film murdered journalist gauri lankesh made director amr ramesh ramesh knew gauri lankesh personally said shocking see lie pool blood fateful day ill never accept killing added focus killed gauri done clarity',
#  'cabhailing startup uber raised billion japans softbankled team investors according reports shares purchased existing shareholders value uber approximately billion roughly discount startups recent valuation billion reports added team uber softbank holding largest stake',
#  'reacting frances yearold forward kylian mbappaa scoring two goals knock argentina world cup user tweeted sweating room playing xbox everyday tweets read asking asl random people online even bank account',
#  'ets regulator sebi imposed penalty aaa1 lakh themami chairman rs agarwal case related amrutanhealthcare ahl regulator said desire expressed themami chairman buy ahl without first discussing companys board reckless statthement impacted trading well share price ahl',
#  'usbased telco att received criticism rivals misleading users labelled faster network logo responding telco verizon said wireless industry must resist potential overhype underdeliver weaaare laying network foundation ewe enable faster speedsupgrade itaaas ready att stated',
#  'finance minister arun jaitley presented union budget twitter user wrote since birth seen two types budget bad budget nothing middle class good budget nothing middle class moral budget never average people rthemthember rthemthember best worst another tweet read',
#  'bjp leader subramanian swamy allegedly said superstar rajinikanth committed financial fraud substantial proof rajinikanth join politics hard continue unfit political work swamy added swamy also termed talks rajinikanth joining politics media hype',
#  'indian legspinner yuzvendra chahal celebrating th birthday today person represent india chess cricket chahal listed world chess federations official site national chess champion represented india world youth chess championship chahal taken international wickets',
#  'many buildings mumbai issued notices flouting fire safety norms mumbai fire brigade department total buildings audited department ber buildings fail comply notice within stipulated time termed unsafe buildings department said',
#  'indian football team defeated sixtime world champions argentina despite reduced men cotif cup match spain indian side meanwhile managed register win current asian champions iraq waff championship amman indias first win iraq age category',
#  'chinas largest oil gas producer petrochina planning open first indian office mumbai according reports company registered petrochina international india total paidup capital aaa1 crore mumbai petrochina reportedly plans trade oil products crude oil indian office',
#  'yearold mechanical engineer quit job multinational company walked km across states raise awareness protest child begging ashish sharma said motivated undertake walk seeing children begging streets delhi claims rescued rehabilitated nine children juvenile homes',
#  'pakistan foreign minister khawaja muhammad asif sunday accused india us involved international conspiracy sabotage indus waters treaty reports suggest asif may referring world bank earlier permitted india construct dams jhelum chenab rivers despite opposition pakistan',
#  'claiming favour ram mandir ayodhya samajwadi party founder mulayam singh yadavs dterinlaw aparna yadav wednesday said im bjp lord ram aparna contest general elections uncle shivpal singhs pragatisheel samajwadi party lohia added full faith process respected court',
#  'video shows indias richest man mukesh ambani holding dter isha ambanis hand walking towards fiancaa anand piramal engagthement certhemony italys lake como mukesh ambani followed ishas recentlyengaged twin brother akash fiancaae shloka mehta threedaylong celebration couples engagthement planned italy',
#  'death toll magnitude earthquake struck iraniraq border sunday risen leaving injured irans western kermanshah province worst hit officials said earthquake prompted around aftershocks one powerful earthquakes since one hit iran killing people',
#  'one among indians lived areas particulate pollution exceed safe levels according iit bombayled study lakh deaths india attributed fine toxic pm pollutants predicted cause least lakh deaths deaths rural areas report stated',
#  'actress preity zinta took instagram share throwback picture aishwarya rai bachchan omg look found among old photos us posing night worldtour wrote preity along picture picture also features television host mini mathur celebrity hairstylist avan contractor',
#  'mumbai police sunday arrested two men allegedly posed themployees ewallet paytm stole aaa1 hotel managers account accused reportedly transferred money two aides stealing customer id password managers phone complained minor issue account',
#  'delhi police made security arrangthements issued alerts areas bordering delhi prevent backlash dera chief gurmeet ram rahim convicted rape case cbi court friday vehicles bound haryana punjab dera sacha sauda sect based checked thoroughly police said',
#  'actor anil kapoor revealed refused attend first international indian film acadthemy iifa awards thought totally rigged anil added thought go obviously going give award despite absence awards categories nominated',
#  'ukbased study claims tyrannosaurus rexs sheer size meant could move high speeds running attthempts would simply broken dinosaurs legs researchers simulated moving dynamics trex found peaked kmph maximum stress limits findings suggest dinosaur could pursue prey highspeed chase previously thought researchers said',
#  'aishwarya rai said pursued filmmakers even beauty pageants dharmesh darshan offered raja hindustani yash chopra wanted launch maine toh mohabbat kar li became dil toh pagal hai added aishwarya said admirer mani ratnams cinthema iruvar debut film happened',
#  'wriddhiman saha scored maiden double century rest india beat ranji trophy champions gujarat win irani trophy six wickets tuesday shared run fifthwicket stand cheteshwar pujara scored th firstclass century irani trophy annual oneoff match played ranji winners rest india team',
#  'alqaedas chief bomb maker ibrahim alasiri probably sophisticated terrorist bomb maker planet killed ythemen last year reports quoting us officials said ibrahim tried blow airliner us detroit also involved plot hide explosives printer cartridges shipped us',
#  'anil ambaniled reliance communications expects complete aaa1crore assets sale stend also agreed pay aaa1 crore settle dues swedens ericssonnthe suprtheme court st approved settlthement arrived rcom ericsson rcom also entered agrethement mukesh ambanis reliance jio sell telecom business assetsn',
#  'cpim general secretary sitaram yechury alleged prime minister narendra modis campaign triple talaq communal campaign yechury slammed modi taking steps various issues concerning women including women reservation bill yechury said opinion triple talaq go along practices prevailing religions',
#  'jawahar lal rajpoot bjp mla jhansis garautha constituency reached uttar pradesh assthembly bullock cart monday ing first day th state assthembly later owner bullock cart claimed mla refused pay rent promised using cart',
#  'b hariku deputy superintendent police keralas neyyattinkara evading arrest accused causing yearold electricians death found hanging home tuesday harikuhad allegedly pushed man front speeding vehicle altercation parked cars mber run since',
#  'us navy aircraft carrying crew mthembers passengers crashed pacific ocean wednesday flying aircraft carrier uss ronald reagan conducting naval drill japan eight personnel recovered search operation launched missing three officials said cause crash established yet',
#  'asserting friendship pakistan china bedrock strategic stability region pakistan prime minister shahid khaqan abbasi said countries iron brothers praising billion chinapakistan economic corridor cpec abbasi said annals history sinopakistan relations find parallel',
#  'least people killed others injured car bomb attack near busy taxi stand afghanistans khost province first day ramadan according reports attack responsibility claimed taliban reportedly targeted afghan police providing security us forces eastern afghanistan',
#  'increase job growth rates salary hikes blockchain development fastest growing skill set highest indthemand themployers iiitbangalore upgrad introduced pg certificate program blockchain technology tt leading experts ibm dcb bank bankchain elthemential springrole upgrads learning experience enabled career transitions across programs',
#  'indianorigin royal mail postman sentenced months imprisonment stealing debit cards birthday voucher surbjit singh khera stole two punjab national bank cards pin numbers withdrawing aa aaa1 atm machines khera whose sentence suspended two years due heart condition postman years',
#  'ecommerce major amazon aerospace startup blue origins founder jeff bezos saturday said permanent human settlthement built one poles moon water ice poles moon bezos stated said time go back moon time stay',
#  'family crpf jawan yred sukma attack abhay mishra claimed suffered bullet injury month ago granted leave come home given bulletproof jacket mishras widow said also questioned mishra posted elsewhere already completed three years chhattisgarh',
#  'sunil gavaskar said following steve smiths brain fade bengaluru test australia got one referrals right think got seven spot brain fade controversy gavaskar said smith turned towards dressing room taking review bengaluru later called brain fade',
#  'green versace dress worn jennifer lopez grammy awards led creation google image search googles exceo eric schmidt revealed aaa became popular search query time making search giant realise image required answer popular search sparking creation google images',
#  'yearold american awarded million compensation wrongly jailed years robbery likely committed lookalike richard anthony freed ricky amos found robbery victims could differentiate two amos also denied crime tried due passage time',
#  'trivandrum archbishop soosa pakiam urged christian schools include constitution literacy part moral science curriculum stating children love constitution added highly dangerous hatred fear invoked among various groups shortcut power constitution defines des basic character nation said',
#  'platoon indian army monday joined rescue operations search miners trapped inside rathole mine meghalaya officials said soldiers already started setting camps near tragedy site officials added soldiers providing logistics administrative support navy divers reports said',
#  'google ceo sundar pichai said feels pain every time company publishes fake news views big responsibility get right google criticised earlier week failing weed fake news following las vegas shooting pichai also said thinks artificial intelligence could fix problthem user privacy heuristically',
#  'indigofs parent interglobe aviation tuesday reported yearonyear increase net profit aaa1 crore mber quarter compared aaa1 crore year ago companys revenue quarter rose aaa1 crore indigo domestic aviation et nearly planes operates daily flights',
#  'yearold pakistani boy hearing speech disabilities lodged indian juvenile home crossing indian territory without travel documents may year acquitted comes pakistan high commission new delhi wrote indian external affairs ministry ensure early release repatriation boyn',
#  'virender sehwag sourav ganguly sunil gavaskar england champions trophy dined together indiapakistan clash sunday ganguly sehwag accompanied wives children sehwag shared picture writing blood makes related love loyalty makes family great time legends sunnysir dada family',
#  'indian opener rohit sharma responded sarcastically sports journalists tweet wherein latter stated openers sharma shikhar dhawan would play new ball second indianew zealand ti twitter users responded sharmas reply tweets like classic hitman hitting park twitter',
#  'central information commission ordered make public statthement nathuram godse along records related mahatma gandhis assassination one may disagree nathuram godse coaccused cannot refuse disclosure circulation opinion cic stated cic said since information years old cannot withheld',
#  'china managed score overs icc world twenty asia region qualifier match thailand batsmen scoring less runs chinas innings included two fours number nine batsman wang ya topscoring thailand chased target balls rthemaining',
#  'actor chris evans known playing superhero character captain america took dig us president donald trump misspelling word heal heel tweeting free speech rally boston trumps tweet deleted replaced tweet proper spelling earlier chris said feels rage trump elected president',
#  'addressing music awards certhemony mumbai vice president venkaiah naidu said music used national integration spread humanity love affection seva mns chief raj thackerays late father musician shrikant thackeray also felicitated certhemony organised mumbai bjp unit chief ashish shelar',
#  'pakistans suprtheme court given hours investigation team arrest culprit behind rape murder sevenyearold girl minors body found garbage pile five days went missing ary kasur district recently authorities arrested man treated prime suspect',
#  'actor shahid kapoor reacting burning sets upcoming film padmavati said unfortunate something like happened second time added aware responsible vandalism earlier jaipur director sanjay leela bhansali manhandled protesters films shooting',
#  'carnegie mellon university researchers developed printing method produces flat sheets objects fold ththemselves take shape upon heating used printer produce flat plastic itthems predetermined shapes chair boat bunny technology compile shape thermoplastic sheets within seconds without human intervention',
#  'union minister state electronics information technology pp chaudhary tuesday said custom triple talaq practised muslim men divorce wives indian constitution nothing constitution according cannot difference basis religion caste gender added',
#  'number women ceos fortune list increased record years list also first feature latina ceo pge corporations geisha williams took top role newcomers include chocolate firm hersheys michele buck toy company mattels georgiadis',
#  'many persons killed others injured saturday truck rammed two autorickshaws van rampura km chitradurga karnataka truck first hit one autorickshaws one tyres burst police said victims killed mishap included eight men seven women',
#  'lewis hamilton equalled michael schumachers alltime record formula one pole positions securing pole belgian grand prix saturday triple world champion defeated title rival sebastian vettel ferrari seconds achieve seventh pole season hamilton currently second driver standings points behind vettel',
#  'miss moscow oksana voevodina got ied yearold malaysian king sultan muhammad reportedly russia last week wedding held russian capital moscow incorporated islamic russian traditions according reports voevodina converted islam changed name earlier year reports added',
#  'facebook ceo zuckerberg pledged hire reviewers rthemove objectionable content faster following increase number violent videos uploaded platform facebook criticised taking long rthemove content last month video thai man killing monthold dter available hours rthemoved',
#  'uber drivers drivers us transport people app average earned less five years ago according report report also showed average monthly payments worked transportation app given month ined',
#  'spencer launching cafes designed provide space people share stories mental health initiative soothe stressed shoppers retailer partnering comedian ruby wax launch frazzled cafe project uk said sessions therapy aimed provide space people talk openly',
#  'lightyear unit measure astronomical distances time confused many one lightyear distance travelled light year equalling trillion km sun lightminutes away earth implying light sun takes minutes reach earth whereas moon lightsecond away',
#  'yearold maid attthempted suicide wednesday jumping th floor building escape torture themployer haryanas faridabad girl burn injury body rescued fell bird net balcony th floor drs reportedly said girl starved long',
#  'tthempo lost control ran four school children allegedly skipping school mumbai tuesday also hit autorickshaw parked side road one children died spot two said critically injured fourth danger driver tthempo absconding',
#  'us released first video former alqaeda leader mastermind osama bin ladens son hamza bin laden adult one hourlong video shows hamza trimmed moustache beard wedding hamza poised lead alqaeda threatened revenge us assassinating father',
#  'charles dayot mayor french town followed promise eat rodent losing bet champions league football match paris saintgermain barcelona following barcelonas first leg loss psg dayot said barca qualifies ill eat rat ill vote leftwing presidential candidate jeanluc melenchon',
#  'mumbaibased healthtech startup dlk raised million seed round led vc firm khosla ventures matrix partners india investors including altair capital liquid ventures yc partner paul buchheit vy capital also participated round founded dlk mobile app allows users save medical files cloud',
#  'responding letter written apple investors regarding iphone addiction among youth companys shareholder ross gerber said invest things addictive also said addictive things profitable however apple said statthement offered range controls iphones since allow parents restrict content',
#  'essar group sold equinox business parks commercial property mumbais bandrakurla complex brookfield asset managthement aaa1 crore acre business park comprises four towers leasable office space million square feet companies occupy space business park experian tata communications crompton greaves lafarge',
#  'rajkumrao says birthdays make awkward excited nervous birthday year film stree released day st film close heart fact releasing birthday makes experience special added rajkumturned years old friday',
#  'interaction children government pri school th birthday monday prime minister narendra modi said students important ask questions never feel afraid ask questions added important aspect learning also asked students learn various skills',
#  'days triple talaq victim ishrat jahan joined bjp lawyer activist nazia elahi khan also joined party thursday jahan one five petitioners case instant triple talaq banned suprtheme court st jahans husband divorced phone dubai',
#  'pm narendra modi sunday said lakh villages india ared open defecation free odf rural india sanitation coverage added crore households provided toilets india moving towards liberation open defecation much prior target ber said',
#  'appreciating photojournalist wasethem andrabi immediately rushing help injured crpf constable mber encounter jammu kashmir crpf dg rr bhatnagar said grateful photojournalist constable grievously injured stone hit head following wasethem rushed aid camera slung one side',
#  'yogeshwar dutt bronze olympics said quit wrestling prepare commonwealth games gold medallist bajrang punia olympics since days showed spark want people india see yogeshwar bajrang added want better said',
#  'congressled opposition called nationwide protests pm narendra modiled government thember recent fuel price hike diesel petrol brought gst modi government refused fuel prices rising upa regime taxes reduced take burden people congress leaders said',
#  'filmmaker sanjay leela bhansali launch actor jaaved jaaferis son meezan bollywood meezan assisted bhansali film bajirao mastani said chosen auditioning role bhansali reportedly coproducing film bhansali productions directed mangesh hadawale known directing thi film tingya',
#  'japanese conglomerate softbank may invest million bengalurubased food delivery startup swiggy according reports chinas tencent alibaba indian ecommerce major flipkart also talks invest food delivery startup reports added earlier may swiggy raised aaa1 crore funding led naspers',
#  'chinese kindergarten teacher jailed months pricking four children needles also barred working minors five years serving sentence behaviour seriously damaged physical mental health minors beijing court said adding abuse result lasting injury',
#  'army major three jawans yred tuesday foiling infiltration attthempt jammu kashmirs gurez region encounter took place security forces patrol intercepted eight militants trying enter country least two militants killed four militants ran back pakistanoccupied kashmir',
#  'us woman survived drinking water radiator car crashed coastal cliff california according police officials angela hernandez found hikers friday saw wreckage car partially submerged bottom cliff authorities said fair stable condition',
#  'ruhaan alva yearold boy bengaluru easykart championship gokarting tournament lonato italy monday ruhaan finished first easykart category racers aged nine years started pole position among racers lap race overtaking two competitors final lap finish first',
#  'yearold girl along boyfriend two minors aged arrested tamil nadu allegedly killing mother girls mother disapproved relationship boyfriend met facebook last year never met person yearold sought help boyfriend sent two minors',
#  'india opener rohit sharma said celebrate century south africa fifth odi tuesday involved runouts virat kohli ajinkya rahane earlier innings hundred gone next game play hundred scored going matter much added',
#  'credit rating agency moodys said expects flipkart continue generate losses next years however added wals acquisition stake flipkart credit positive creditpositive view based indias compelling features including billion residents economy generates annual gdp growth moodys said',
#  'choreographerfilmmaker farah khan took social media share picture actress dressed actor amitabh bachchan captioned guess jumma chumma aa la amitabh picture sets upcoming tv show lip sing battle twitter users speculated actress dressed amitabh shilpa shetty',
#  'american chipmaker intels ceo brian krzanich sold million worth companys stock mber last year according reports report comes researchers found vulnerability intel chips could compromise users passwords personal photos messages computers phones globally intel admitted flaw shares fell around',
#  'outgoing trai chief rs sharma tuesday asserted disclosing aadhaar number increase ones digital vulnerability comes shared aadhaar number twitter challenging anyone show number misused harm claimed gotten access bank account number themail sharma dismissed claims',
#  'world health organization routinely spends million year travel executives far spends fight aids tuberculosis malaria combined according report associated press however refuted allegations said less half travel costs staff',
#  'uk queen elizabeth ii given official consent wedding grandson prince harry american actress meghan le prince harry fifth line throne requires monarchs permission succession crown act legislation mandates permission first six royals line throne',
#  'usbased startup wallflower labs developed device hooks electric stoves notify users risk fire aaa1 device send notification users phone rtheminder turn stove also learns users cooking habits alerts stove longer usual',
#  'artist khushboo akash davda presented artwork made five lakh pearls prime minister narendra modi artwork depicts map india image modi dimensions feet took artist thread length kilometre hours prepare artwork',
#  'talking ranbir kapoor portraying sanjay dutt upcoming biopic sanju arshad warsi said matter cannot sanju original added way sanju walks talks actor imitate earlier salman khan said sanjay portrayed older self film',
#  'gst network initiated process mining data analyse taxpayer behaviour detect tax evasion according reports gstn soon solicit proposals companies needs tools manpower data analytics ceo prakash kuhas said able slice dice data whichever way want added',
#  'karnataka state cricket association announced indian batsman manish pandey replace vinay kuas captain state team across three formats domestic circuit keeping future karnataka cricket mind selectors felt start grooming another captain manish best choice kscas secretary said',
#  'addressing un general assthembly meeting india saturday sought zero tolerance criminal acts committed personnel serving un missions globally asserted crimes damaging image credibility world body india also asked un provide data cases misconduct un refused waive immunity personnel',
#  'mukesh ambaniled reliance jio clarified launched app called jiocoin company said would take legal action people solicit make investments jiofs name misguide public notably following reports jio planning create cryptocurrency jiocoin fake jiocoin apps appeared google play store',
#  'us president donald trump sunday said deal signed north korea completely denuclearise korean peninsula may work follows reports north korea increased production enriched uranium secret sites trump earlier claimed deal ended nuclear threat posed north korea',
#  'kerala high court recently ded name child interfaith parents could de contested others choices court court chose name johan sachin satisfy wishes parents couple approached high court unable obtain birth certificate child',
#  'former australian cricketer shane warne along teammate found guilty accepting money bookmaker exchange leaking information legspinner also banned international cricket year failing drug test world cup warne later claimed drug given mother weight loss',
#  'sharing picture kangana ranaut raveena tandon wrote one started allkangana ranaut got us slumber onto airport catwalk airportlooks airportdiaries fashionpaparazzi picture selfie raveena seen wearing leather jacket red lipstick kangana seen wearing black jacket sunglasses',
#  'shriram capitals ajay piramal said piramal group idfc shriram committed following rbi guidelines shrirams merger idfc stressing shriram capital strategic investor said naive assume shrirams backdoor entry banking sector notably groups entered day exclusive talks merger',
#  'karnataka high court friday stayed state governments ban registration use twowheelers engine capacity less cc equipped pillion seats comes two private motor companies challenged constitutional validity rule karnataka motor vehicles rules based government issued circulars ban',
#  'team india opener shikhar dhawan took instagram share video singing bollywood song mere anmol ratan captain virat kohli former captain ms dhoni flight mere anmol ratan mahi viratkohlibak best like day sorry bad singing though dhawan captioned video',
#  'omitted indiasri lanka limitedovers series yuvraj singh said earlier failed three fitness tests passed one recently yuvraj claimed aims play till take call im afraid failure ive gone ups downs ive seen defeat pillar success yuvraj said',
#  'talking ongoing season ipl bollywood actor amitabh bachchan tweeted saidthis season ipl something elsea revelationwhat gameswhat incredibly exciting resultsalmost every game tense last finish amitabhs tweet came rcbcsk srhkxip matches csk chased run target srh defended runs kxip',
#  'former pakistani cricketer hanif mohammad batted minutes test west indies knock runs ended ary innings covering nine consecutive sessions enough encompass football matches included boundaries singles twos threes run knock helped pakistan draw match',
#  'canadas ambassador us david macnton said us indicated pursue huawei cfo meng wanzhous formal extradition canada meng dter chinese telecoms giants founder ren zhengfei arrested us request last month allegations bank fraud related sanctions iran deadline filing extradition request ary',
#  'students government school madhya pradeshs tikamgarh district give exams schoolds terrace bjp mla organising cultural event inside prthemises students forced write exams loud music playing dancers performing school ground district collector abhijeet agrawal also attended event',
#  'mumbai sessions court recently sentenced casting director named ravindranath ghosh life imprisonment harassing raping yearold aspiring actress also took inappropriate photos sent ththem husband themployer court imposed fine aaa1 lakh ghosh pay aaa1 lakh survivor compensationn',
#  'technology giant apple acquired danish machine learning startup spektral around million last year mber startup previously named cloudcutout visual effects company applies machine learning image video editing apple recently acquired usbased startup akonia holographics manufactures lenses ented reality glasses',
#  'japanese conglomerate softbank invested million american coworking workspace startup wework valuing startup billion earlier reports suggested softbank planning invest total billion wework founded wework rents desks offices small businesses freelancers people seeking tthemporary working space',
#  'cctv footage captured moment threewheeler crashed mobile store chinese city taixing threewheeler belonged owner nearby store apparently left running following pet dog accidentally stepped acceleration pedal one injured mishap',
#  'singer zayn malik took instagram share dubstepstyled cover song allah duhai hai salman khan starrer race fans zayn malik said sharing snippet cover instagram profile zayn previously posted covers kailash khers teri deewani allah ke bande',
#  'sholay original ending featured character thakur played sanjeev ku killing films villain gabbar portrayed amjad khan however sholays director ramesh sippy change ending censor board thought scene violent film starred dharmendra amitabh bachchan jaya bachchan released years ago st',
#  'maharashtra navnirman sena mns chief raj thackeray slammed prime minister narendra modi allegedly supporting social media trolls silence voices dissent stating support could lead anarchy thackeray alleged bjp resorts police machinery suppress opposition bjp uses social media trick common man misinformation claimed',
#  'west bengal government compensate families killed injured accidents natural disasters within hours compensation aaa1 lakh case deaths aaa1 lakh severe injuries part ensure speedy disbursal compensation said disaster managthement minister javed ahmed khan nn',
#  'us republican senator bob corker said president donald trumps comments publicly castrating state secretary rex tillerson limiting efforts dealing north korea comes tillerson said us directly communicating north korea trump responded saying tillerson wasting time talking north korean leader kim jongun',
#  'speaking stardom bobby deol said wish knew reached level twothree movies never realised thati wasnormal wish noticed maybe would made focus losing added bobby said never thought people competing',
#  'talking terrorist attack sunjwan army camp jammu killed five jawans defence minister nirmala sitharaman monday said pakistan pay misadventure also revealed masood azharled jaishemohammad jthem responsible attack terrorists controlled handlers across border',
#  'reacting zimbabwes recent odi series win sri lanka indian offspinner ravichandran ashwin said results like healthy game tomorrow afghanistan may beat someoneso way sport needs go added yearold ashwin part india squad play first full series sri lanka eight years',
#  'three women arrested tuesday connection poisoning prasad tthemple chikkaballapur district karnataka two women died several people hospitalised complaints vomiting loose motions police earlier said tthemple managthement responsible women brought prasad ththemselves distributing',
#  'criticising government violent protests padmaavat aimim president mp asaduddin owaisi wednesday said pm narendra modis inch chest muslims rajputs alleging bjp helping groups like karni sena become mainstream parties owaisi said rule law country',
#  'group people pakistans peshawar held candlelight vigil honour veteran actor shashi kapoor passed away monday meet held outside shashis ancestral home built late grandfather dewan basheswarnath kapoor notably shashi honoured padma bhushan dadasaheb phalke award',
#  'yearold newlywed bride jumped first floor house ct fire due lpg cylinder blast uttar pradeshs ghaziabad monday fire spread reportedly least people inside house bride escaped fractured leg three women suffered minor burns',
#  'actress priyanka chopras fiancaa singer nick jonas recently appeared tonight show revealed priyanka likes prick couples possible celebrity nickname likes prick like one added jonas talking couples roka certhemony india jonas said parents blown away love shared among people',
#  'tamil nadus ruling party aiadmk moved madras high court seeking ban ttv dhinakarans party amma makkal munnetra kazhagam flag claiming similar tamil nadu cm edappadi palaniswami said dhinakarans party flag black red white like flag aiadmk sidelined leader launched ammk h',
#  'hotel built abandoned openpit mine two floors ground neared completion china hotel floors underground two floors underwater feature nearly guest rooms underwater restaurant opens may',
#  'kuwait proposed setting international protection mission palestinians draft un security council unsc resolution presented kuwait calls measures guarantee safety protection palestinian civilians occupied palestinian territories gaza strip palestinians killed israeli firing last two months',
#  'delhi reportedly get first lingerie vending machine indira gandhi international airport later month project launched luxury brand lingerie shop earlier installed indias first lingerie vending machine mumbai aimed breaking taboo attached buying innerwear public machine provide prepacked lingerie many styles sizes',
#  'pakistani actress mahira khan said bollywood never really aim focus always working pakistan added think tell story better story country talking call ban pakistani artistes india said time sad angry',
#  'suprtheme court friday stayed aaa1crore penalty imposed cthement companies competition commission india cci allegations cartelisation court asked companies deposit amount competition regulator imposed highest penalty aaa1 crore aditya birla group firm ultratech cthementn',
#  'actress disha patani worshipped students hindu college delhi hopes losing virginity next six months celebration annual event valentines day popular actress chosen worshipped damdami mai always condoms used rate virgin tree said student',
#  'goair kochimumbaidelhi flight forced make themergency landing goa wednesday night due technical snag airline said flight powered pratt whitney engines faced repeated technical snags notably flyers claimed engines themitted strange sounds flight taking',
#  'usbased researcher antonio paris solved second radio signal space recorded observatory sources like asteroids exoplanets stars ruled prof paris suggested signal might come comet comets discovered themitting similar signals explaining mystery prompted astronomer scribble wow back',
#  'south african cricketer kagiso rabada dropped twice indian fielders ravichandran ashwins consecutive deliveries second test sunday th first captain virat kohli dropped rabada slips confusion rushing fielders hardik pandya mohammed shami resulted another dropped catch next ball',
#  'kangana ranaut said plans getting ied soon adding please give deadline till next uary kangana said initially given deadline mber year earlier revealed relationship said indeed man life enjoying',
#  'archaeological survey india unearthed chariots swords caskets dating back bc bc uttar pradeshs baghpat reportedly firstever physical evidence chariots dating back bronze age based rthemains excavated asi said sethems like region belonged warrior class past',
#  'guide dog named roselle led blind owner michael hingson storeys world trade centres north tower attack labrador guided hingson friends home attack killed nearly people carried militants associated militant group alqaeda day years ago',
#  'indian captain virat kohli applauded cheered impressed ashish nehra using foot field ball final international match wednesday yearold pacer stopped ball using right foot making bounce plucked using right hand throwing towards keeper',
#  'juvenile justice board gurugram tried juveniles since ary adults amendments juvenile justice act convictions taken place seven cases trials still recently court upheld boards sion try yearold juvenile accused sevenyearold boys murder gurugram school',
#  'us court reduced damages imposed tata consultancy services half trade secrets case us healthcare software firm epic systthems court reduced damages million million granted jury verdict last year epic accused tcs illegally acquiring information create healthcare systthem',
#  'elon muskled tesla let go approximately workforce effort reduce costs become profitable billionaire said themail themployees cuts almost entirely made salaried population production associates included said earlier musk told themployees tesla undertaking thorough reorganisation',
#  'billionaire investor george soros transferred billion open society foundations works promote dthemocracy human rights freedom press founded soros operates countries billion figure amounts nearly soros total net worth stands billion according forbes',
#  'indian football teams participate upcoming asian games indian olympic association refused clearance ioa took sion sticking policy topeight finish teams previous edition qualifying criterion first time since indian football team take part asian games',
#  'gurudwara uttarakhands joshimath saturday offered prthemises devotees offer eid aladha namaz halt prayers gandhi maidan due heavy rains meanwhile pm modi took twitter extend wishes wrote may spirit harmony brotherhood togetherness furthered society',
#  'jammu kashmir government thursday suspended hizbulmujahideen chief syed salahuddins son syed shahid yusuf agriculture department days arrested terrorfunding case yusuf allegedly received funds international wire money transfer hizbul militant aijaz bhat according nia official received funds',
#  'google cofounder larry page uber cofounder travis kalanick group executives friday ordered testify technology theft case involving two companies googles selfdriving car unit waymo uary sued uber alleging intentionally hired former engineer anthony levandowski accused stealing documents waymofs selfdriving car technology',
#  'us president donald trumps personal charity trump foundation would dissolved amid allegations three eldest children misused funds new york attorney general filed lawsuit foundation alleging trump used funds presidential campaign settle lawsuits among others rthemaining assets would redistributed charities',
#  'tata group reportedly talks buy majority stake jet airways aiming merge carrier vistara joint venture tata singapore airlines tata looking buy stake owned founder naresh goyal etihad airways stake may also reportedly buy jets loyalty programme jet privilege',
#  'bjp deploy nearly workers part outreach programme teach farmers spiritual religious benefits agriculture programme also include history agriculture current situation farm sector governments achievthements suggestions welfare volunteers reportedly guide farmers make best use central governments policiesn',
#  'cybersecurity researchers discovered fake google chrome extension steals credit card data via web forms visited websites extension title reader flash spread means javascript injection attacks display warnings like flash installed use chrome extension instead extension reportedly available since uary',
#  'north korea vowed strike merciless blow heart us powerful nuclear hammer us attthempts overthrow leader kim jongun comes cia director mike pompeo claimed north koreans would love see jonguns rthemoval called jongun thing dangerous north korea',
#  'us friday rejected proposal solve ukranian crisis holding referendum russian president vladimir putin reportedly suggested idea us counterpart donald trump us said holding referendum would legitimate since crimea control ukranian government putin proposed idea trump helsinki summit',
#  'police said medical examination delhi chief secretary anshu prakash confirmed injuries near face comes day prakash accused aap mlas assaulting direction cm arvind kejriwal midnight meeting kejriwals residence police detained aap mla prakash jarwal alleged assault tuesday',
#  'scientists harvested kilograms labgrown salad greens cucumbers radishes antarctica without dirt daylight pesticides two months per team themployed water nutrient systthem optimising led lighting monitoring carbon dioxide room hope harvest kilograms fruits vegetables week may',
#  'karnataka department collegiate education directed private aided colleges submit aaa1crore excess fee collected ththem students department added government grants colleges failing submit excess fee withdrawn aided colleges legally bound submit stipulated portion excess fee government',
#  'australian pm malcolm turnbull fined aaa1 wearing life jacket steering inflatable boat sydney harbour adding moving boat metres near beach pm said lesson learned ill always wear life jacket dinghy regardless close im shore',
#  'bengaluru family court directed former karnataka minister sr kashappanavars son pay aaa1 crore alimony wife motherinlaw deposed support dterinlaw motherinlaw reportedly informed court affidavit son ied another woman wishes family deserted petitioner without fulfilling tal obligations',
#  'fire broke ary gora bazar et west bengals dum dum resulting death two workers reportedly destroying shops twenty fire tenders rushed spot fire doused eleven hours although officials given cause fire reports said shopkeepers suspect cylinder explosion',
#  'former union minister chidambaram wednesday expressed concern reports government invoked unused section rbi act saying centre hiding facts economy desperate im afraid bebad news today added section rbi act allows government issue directions rbi',
#  'yearold pune man arrested allegedly repeatedly raping yearold stepdter since mber accused runs snacks stall works parttime dance teacher raped minor threatening kill mother minor confided teacher following police complaint lodged arrested',
#  'microsoft thursday said acquired usbased startup lobe builds aibased models help simple draganddrop interface aim simplify ai development everyone company said blog post microsoft recently also acquired bonsai deep reinforcthement learning platform sthemantic machines conversational ai platform',
#  'yearold girl allegedly raped yearold pandal contractor went offer prayers pandal ganesh chaturthi festival agar village maharashtra girl visiting pandal children accused lured pretext took behind venue sexually assaulted later fled area',
#  'punjab cm captain ander singh wednesday condthemned alleged attthempts politicise armed forces saying meant report regimental heads work behest political parties speaking event honour soldiers commonwealth countries lost lives fighting world war',
#  'message peace harmony beautifully portrayed holy quran propagate violence army chief general bipin rawat told group students jammu kashmir thursday said message peace harmony noise made nowhere mentioned quran',
#  'aap mla hs phoolka expressed regret rthemark purportedly linked army chief bipin rawat blast nirankari bhawan amritsar statthement totally misunderstoodit actually congress respected army chief phoolka said adding inadvertent statthement made standing road blown proportion',
#  'chief ministers delhi himachal pradesh haryana rajasthan uttar pradesh uttarakhand signed agrethement friday renukaji dam multipurpose project three storage projects constructed yamuna river two tributaries tons giri renukaji dam multipurpose project yet receive stageii forest clearance environment ministry',
#  'austrias yearold player dominic thithem ended rafael nadals match win streak clay courts season defeating spaniard rome masters quarterfinal friday nadal aiming win eighth title rome said ready upcoming french open aiming tenth title',
#  'journalist arrested reporting zimbabwean first lady grace mugabe donated used clothing including underwear supporters ruling party human rights organisations dthemanded journalists release notably yearold robert mugabe president nearly years zimbabwe grace considered among main contenders power passes away',
#  'donald trumps sixmonth approval rating stands lowest among us presidents last years according national poll published sunday poll found us citizens believe countrys leadership world weaker billionaire took office however trump called poll result bad',
# ...
#  'group cow vigilantes stopped three vehicles transporting cows beat drivers outskirts guwahati assam accusing ththem cattle smuggling per reports attackers claimed belong hindu yuva chhatra parishad incident comes pm narendra modi said killing people name gau bhakti acceptable',
#  'commenting govindas picture sanjeev shrivastava dubbed dancing uncle social media actor ranveer singh wrote chichi sir king video sanjeev dancing govindas aap ke aa se went viral got opportunity meet govinda reality show two ththem danced together',
#  'luxury fashion house prada selling nearly aaa1 paperclipshaped money clip barneys new york polished sterling silver money clip made italy went viral social media twitter users said mood wealthy enough prada money paperclip lmaoooo talking microsoft paperclip',
#  'microsoft cofounder bill gates set make special appearance american sitcom big bang theory preview episode shows character penny played kaley cuoco telling friends gets meet bill gates work episode airs thursday titled gates excitation',
#  'officials visited residence yearold man disabilities haryana create aadhaar card tuesday comes media reported man denied disability pension ration past seven months lack aadhaar earlier faced problthems getting aadhaar fingers',
#  'essar steels committee creditors chosen arcelormittal japans nippon steel sumitomo metal winning bidders company firms would pay aaa1 crore lenders inject aaa1 crore company essar steels promoters ruia family thursday offered pay aaa1 crore settle claims withdraw company insolvency',
#  'avatar sequel film avatar release mber according films facebook page meanwhile avatar release year mber followed avatar mber avatar mber earnings aaa1 crore billion avatar among highestgrossing movies time',
#  'reporter casey stegall handed six pack beer passerby coverage hurricane harvey friday video tweeted fox news stegall seen midcoverage woman comes frame says brought guys galveston beer even gave hug stegall tweeted broadcast',
#  'according reports google developing technology let publishers create visualoriented media content like snapchats discover feature googles new feature mix photos videos text reports added google reportedly talks cnn washington post time vox media among others regarding participation feature',
#  'least one person shot dead four buses set ablaze attack naxals bihars aurangabad area saturday night teams central reserve police force crpf district police later reached spot pictures incident surfaced online show mangled rthemains redcoloured bus gutted',
#  'italian mafia giue dainotti shot head two motorbikers monday riding bicycle palermo city dainotti served two des jail murder robbery released murder comes day th anniversary killing antimafia prosecutor giovanni falcone',
#  'singer daler mehndi granted bail minutes jailed years patiala court human trafficking case singer taken custody punjab police soon convicted daler brother shamsher singh accused illegally sending people abroad disguised mthembers dalers troupe',
#  'mumbai police conducted raid illegal dance bar disguised orchestra bar rescued women hidden cramped closetlike room ventilation wednesday police arrested people bars owner booked attthempt commit culpable homicide women sent shelter city',
#  'speaking india today conclave prime minister narendra modi saturday said basis new india opportunity encouragthement prime minister also spoke goods services tax gst adding gst example delegated dthemocracy gst made us identify federal structure india afresh',
#  'national investigation agency arrested bangladeshi national mohammed jahidul islam bengaluru key accused burdwan blast case operative jamaatul mujahideen bangladesh also said mastermind ary bodh gaya blasts traces explosives electronic devices recovered house',
#  'heavy rainfall bengaluru claimed two lives three people feared washed away overflowing drains couple clearing water home crushed death due wall collapse priest basaveshwaranagar mother dter laggere suspected washed away',
#  'former pakistani hockey player mansoor ahmed reached indian government seeking heart transplant might broken lot indian heartsby defeating indiabut sport need heart transplantfor need indias support said humanity paramount id immensely obliged get visa added ahmed',
#  'google admitted audio issues pixel xl phones design company said allow users record outside selectively dethemphasised frequencies minimise disruptive noises optimise resulting audio earlier users claimed audio quality pixel phones poor video recordings',
#  'indian cricketer yuvraj singh monday shared throwback picture teammates zaheer khan harbhasingh sachin tendulkar vvs laxman sky walking indian teams tour new zealand yuvraj captioned picture turn face sun shadows fall behind throwbackmthemories mondaymotivation livedareinspire',
#  'spanish football club real madrids social media accounts hacked saturday hackers welcoming barcelona forward lionel messi club hackers posted video messis winning goal barcelonas stoppage time victory el clasico last season hackers ourmine claimed responsibility posting internet security proved reals official handle',
#  'national highways authority india nhai chopped trees gurugram develop flyover three underpasses environmentalists criticised nhai move name development meteorological department officials raised concerns possible increase tthemperature degrees',
#  'brazils suprtheme court tuesday named sport recife team league title winners yearlong dispute club flamengo brazils league winner teams crowned league winners two rate leagues run concurrently panel ded sport recife beat flamengo crowned league champions',
#  'man accompanied group friends took kg bathtub full coins apple store russian mall buy iphone xs instagram video showed friends carrying bathtub store car least two scuffles broke group malls security guards',
#  'stampede thember killed pilgrims rajasthans chamunda devi tthemple st rumours landslide caused stampede himachal pradeshs naina devi tthemple killing around people stampede caused jeep went control makara jyothi day keralas sabrimala killed',
#  'technology companies intel samsung backed lawsuit us government agency ftc chipmaker qualcomm unfairly using patents harm competition company accused abusive patent commercial practices refusing license technology earlier iphone maker apple also filed billion lawsuit qualcomm charging excessive royalties',
#  'visually impaired people cannot recognise newly issued aaa1 note identification differentiate denominations pil filed delhi high court claimed adding matter needed urgent attention public importance court sought responses centre reserve bank india within two weeks',
#  'bloomberg video explores ongoing usnorth korean tensions latters nuclear programme could play war analysis predicts surgical strike us north korea prompt reclusive state launch massive artillery fire south korea attack could escalate nuclear war',
#  'speaking indian captain virat kohli south african batsman ab de villiers said passion something love watching giving passion old age de villiers also said kohli learnt control themotions stay calm pressure make levelheaded sions',
#  'police us city sacramento shot dead africanamerican man mistaking cellphone hand gun camera footage released wednesday revealed police fired gunshots stephon clark suspecting behind reported incident violence neighbourhood investigation launched killing',
#  'rush get office every morning youngsters often end skipping breakfast important meal day combat problthem mtr launched range indian breakfast prepared three minutes simply adding hot water mtraaas range min indian breakfast includes halwa poha upma oats',
#  'us president donald trump thursday signed executive order impose tariff steel imports tariff aluminium imports us excluding canada mexico taxation however added tariff effective days give time us allies negotiate exthemption',
#  'prince persia actress gthemma arterton revealed working film producers flew personal trainer ensure losing weight role even workouts gym filmed gthemma added producers would constantly call trainer check gym actress called experience traumatic n',
#  'following mukesh ambaniled reliance jiofs latest offers incumbents would also make comparable offers subscribers even cost shortterm revenue loss deutsche bank ets research said report three incumbents namely bharti airtel idea vodafone sufficient spectrum compete jio added notably jio began charging services l',
#  'talking comparisons made acting front mother amrita singh sara ali khan said extrthemely fine actor take long time compared sara made bollywood debut sushant singh rajputs kedarnath seen opposite ranveer singh rohit shettys simmba',
#  'ford motor company told salaried themployees face unspecified job cuts part us carmakers billion restructuring secondlargest us automaker global workforce around yearold company cut profit forecast secondquarter profit fell nearly half billion',
#  'airports authority india aai hiked penalty amount individuals violating regulations airports person contravening regulations would face penalty compared earlier quantum aai chairman guruprasad mohapatra said penalties increased earlier quantum appropriate changing times',
#  'nobel prizewinning economist robert shiller said sees bitcoin example faddish human behavior im interested bitcoin sort bubble mean disappear burst forever may us added bitcoin currently trading around record',
#  'congress mp pl punia thursday alleged family mthembers rohith vthemula committed suicide hyderabad university illtreated claimed aseds family given notice cancel caste certificate terming shame government punia dthemanded mental harassment family stopped',
#  'video bikiniclad rider thrown horse nightclub us miami surfaced online video shows horse falling ground throwing woman nightclub investigation possible animal cruelty endangering public safety lost licence following incident',
#  'navratriththemed condom advertisthement featuring sunny leone led protests suratbased group hindu yuva vahini message gujarati hoarding translates navratri play love insinuation hoardings condom brand insults religious sentiments hindus said leader hindu yuva vahini',
#  'delhi international airport limited called increasing passenger security fee aaa1 aaa1aaa1 citing severe shortage funds cisf personnel guarding airport delhi airport owes cisf aaa1 crore added pri responsibility ministry civil aviation ensure payment dues cisf',
#  'researchers university central florida developed antiglare film could allow people read sphones tablets even bright sunlight coating inspired nanostructures cover moth eyes prevent light reflecting ththem flexible selfcleaning coating increases readability times different lighting conditions',
#  'nvodafone red postpaid customers stream free movies vodafone play year moreover vodafone red postpaid plan customers also get benefit data unlimited local std calls netflix subscription year',
#  'court uttar pradeshs barabanki district acquitted former amu research scholar gulzar ahmed wani charges sabarmati express blast case due lack evidence resident baramulla district north kashmir wani arrested new delhi jail since',
#  'niti aayog ceo amitabh kant said india needs improve human development index hdi achieve growth around kant said growth possible infant maternal mortality rates high one three children stunted notably india slipped one place rank st among countries hdi',
#  'bank america said money managers showing concerns earnings growth seeing us equities surge records ominous sign according banks latest survey managers say corporate profits improve start year time record said equity ets overvalued',
#  'us president donald trump said country russia get along hope good relations russia say loud clear ive saying years think good good relationships russia trump added',
#  'wife yearold dalit christian murdered telangana last week accused father getting husband killed adding father capable woman reportedly fivemonth pregnant also claimed father asked undergo abortion victim hacked death front',
#  'prime minister narendra modi reportedly asked ministry defence initiate theatre commands military would put troops resources three forces one officer new initiatives including appointment fourstar general look issues armed forces would also taken end year',
#  'australias silverwinning olympic medalist jack bobridge arrested perth charges selling supplying mdma recreational drug yearold cyclist arrested police raided home undercover operation bobridge retired prthematurely cycling due rheumatoid arthritis end last season winning second olympic silver',
#  'mayor us town hell elijah daniel impeached wednesday three hours took office aring heterosexuality illegal ban copyandpaste trumps muslim ban heterosexuals instead yearold said interestingly become mayor giving town organisers small fee',
#  'shiv sena chief uddhav thackeray criticised bjpled centre taking action karnataka governments offensive dthemand rate flag said part bjps plan win upcoming karnataka assthembly elections state government also slapped sedition charges dthemand added',
#  'spanish judge issued international arrest warrant ousted catalan president carles puigdthemont fled belgium government dissolved spains national government regions independence aration puigdthemont faces years prison found guilty sedition rebellion misspending public funds',
#  'china ukbased researchers undertook largest study looking components dietaaafat carbohydrates proteinaaathat caused weight gain mice mice fed different diets three months equivalent nine years humans based similarities metabolism researchers concluded fat consumption could sole cause weight gain humans',
#  'rjd chief lalu prasad yadavs wife rabri devi children charged benami transactions act income tax department connection land deals worth crore tax evasion department seized total plots belonging lalus dter misa bharti husband excm rabri devi deputy cm tejaswi yadav',
#  'pakistan tuesday placed former pm nawaz sharif dter ams name exit control list ecl following conviction avenfield reference corruption case per reports placed list barred leaving country sharif may return pakistan london later week',
#  'ahead testimony regarding recent data scandal facebook companys ceo zuckerberg said would consider resigning position im confident going able work issues zuckerberg said earlier zuckerberg said still best person lead facebook',
#  'filmmaker ketan mehta sent legal notice kangana ranaut stop production film manikarnika accused kangana producer kamal jain hijacking original project called rani jhansi warrior queen mehta added since contact kangana project access script drafts',
#  'delhi high court said undue sympathy towards convicts awarding inadequate jail term undermines public confidence efficacy law upholding yearlong term awarded trial court man rape dismissing mans plea reduction punishment justice sp garg said awarding inadequate sentences serious threat society',
#  'terrorists shot dead army jawan aurangzeb jk thursday abducting released last photo taken ththem killing jawan enroute home celebrate eid family abducted terrorists hailing village salani jks poonch yearold aurangzeb joined army',
#  'pictures showing policthemen taking away beer cans truck overturned national highway uttar pradeshs hathras district surfaced policthemen claimed keeping raiders away truck overturned driver tried avoid collision school bus injured driver helper taken hospital',
#  'argentine defender cristian villagra plays argentinas top division take time football donate bone ow brother gonzalo suffering leukthemia yearold defender said try assist much possible donor fills pride makes feel good']

# %%
from transformers import PegasusForConditionalGeneration, PegasusTokenizer, Trainer, TrainingArguments
import torch


class PegasusDataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels
    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels['input_ids'][idx])  # torch.tensor(self.labels[idx])
        return item
    def __len__(self):
        return len(self.labels['input_ids'])  # len(self.labels)


def prepare_data(model_name,
                 train_texts, train_labels,
                 val_texts=None, val_labels=None,
                 test_texts=None, test_labels=None):
  """
  Prepare input data for model fine-tuning
  """
  tokenizer = PegasusTokenizer.from_pretrained(model_name)

  prepare_val = False if val_texts is None or val_labels is None else True
  prepare_test = False if test_texts is None or test_labels is None else True

  def tokenize_data(texts, labels):
    encodings = tokenizer(texts, truncation=True, padding=True)
    decodings = tokenizer(labels, truncation=True, padding=True)
    dataset_tokenized = PegasusDataset(encodings, decodings)
    return dataset_tokenized

  train_dataset = tokenize_data(train_texts, train_labels)
  val_dataset = tokenize_data(val_texts, val_labels) if prepare_val else None
  test_dataset = tokenize_data(test_texts, test_labels) if prepare_test else None

  return train_dataset, val_dataset, test_dataset, tokenizer


def prepare_fine_tuning(model_name, tokenizer, train_dataset, val_dataset=None, freeze_encoder=False, output_dir='./results'):
  """
  Prepare configurations and base model for fine-tuning
  """
  torch_device = 'cuda' if torch.cuda.is_available() else 'cpu'
  model = PegasusForConditionalGeneration.from_pretrained(model_name).to(torch_device)

  if freeze_encoder:
    for param in model.model.encoder.parameters():
      param.requires_grad = False

  if val_dataset is not None:
    training_args = TrainingArguments(
      output_dir=output_dir,           # output directory
      num_train_epochs=2000,           # total number of training epochs
      per_device_train_batch_size=1,   # batch size per device during training, can increase if memory allows
      per_device_eval_batch_size=1,    # batch size for evaluation, can increase if memory allows
      save_steps=500,                  # number of updates steps before checkpoint saves
      save_total_limit=5,              # limit the total amount of checkpoints and deletes the older checkpoints
      evaluation_strategy='steps',     # evaluation strategy to adopt during training
      eval_steps=100,                  # number of update steps before evaluation
      warmup_steps=500,                # number of warmup steps for learning rate scheduler
      weight_decay=0.01,               # strength of weight decay
      logging_dir='./logs',            # directory for storing logs
      logging_steps=10,
    )

    trainer = Trainer(
      model=model,                         # the instantiated 🤗 Transformers model to be trained
      args=training_args,                  # training arguments, defined above
      train_dataset=train_dataset,         # training dataset
      eval_dataset=val_dataset,            # evaluation dataset
      tokenizer=tokenizer
    )

  else:
    training_args = TrainingArguments(
      output_dir=output_dir,           # output directory
      num_train_epochs=2000,           # total number of training epochs
      per_device_train_batch_size=1,   # batch size per device during training, can increase if memory allows
      save_steps=500,                  # number of updates steps before checkpoint saves
      save_total_limit=5,              # limit the total amount of checkpoints and deletes the older checkpoints
      warmup_steps=500,                # number of warmup steps for learning rate scheduler
      weight_decay=0.01,               # strength of weight decay
      logging_dir='./logs',            # directory for storing logs
      logging_steps=10,
    )

    trainer = Trainer(
      model=model,                         # the instantiated 🤗 Transformers model to be trained
      args=training_args,                  # training arguments, defined above
      train_dataset=train_dataset,         # training dataset
      tokenizer=tokenizer
    )

  return trainer


if __name__=='__main__':
  # use XSum dataset as example, with first 1000 docs as training data
  #from datasets import load_dataset
  #dataset = load_dataset("xsum")
  train_texts, train_labels = x_train[:1000], y_train[:1000]

  # use Pegasus Large model as base for fine-tuning
  model_name = 'google/pegasus-large'
  train_dataset, _, _, tokenizer = prepare_data(model_name, train_texts, train_labels)
  trainer = prepare_fine_tuning(model_name, tokenizer, train_dataset)
  trainer.train()
# Out:
# Some weights of PegasusForConditionalGeneration were not initialized from the model checkpoint at google/pegasus-large and are newly initialized: ['model.decoder.embed_positions.weight', 'model.encoder.embed_positions.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='660' max='2000000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [    660/2000000 1:59:08 < 6033:11:04, 0.09 it/s, Epoch 0.66/2000]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>8.625200</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>8.503600</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>8.374200</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>7.645700</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>7.522800</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>7.306500</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>7.648700</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>7.570100</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>7.002800</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>7.422100</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>7.036100</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>5.735100</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>6.492600</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>6.162300</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>5.845400</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>5.913300</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>5.146900</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>4.757500</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>5.027800</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>4.973700</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>4.895900</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>4.206400</td>
#     </tr>
#     <tr>
#       <td>230</td>
#       <td>4.658700</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>4.781600</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>4.649600</td>
#     </tr>
#     <tr>
#       <td>260</td>
#       <td>4.618800</td>
#     </tr>
#     <tr>
#       <td>270</td>
#       <td>4.662300</td>
#     </tr>
#     <tr>
#       <td>280</td>
#       <td>4.639200</td>
#     </tr>
#     <tr>
#       <td>290</td>
#       <td>4.283300</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>3.653000</td>
#     </tr>
#     <tr>
#       <td>310</td>
#       <td>3.957800</td>
#     </tr>
#     <tr>
#       <td>320</td>
#       <td>4.315700</td>
#     </tr>
#     <tr>
#       <td>330</td>
#       <td>4.130500</td>
#     </tr>
#     <tr>
#       <td>340</td>
#       <td>3.898100</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>4.242000</td>
#     </tr>
#     <tr>
#       <td>360</td>
#       <td>4.471400</td>
#     </tr>
#     <tr>
#       <td>370</td>
#       <td>4.095600</td>
#     </tr>
#     <tr>
#       <td>380</td>
#       <td>4.235700</td>
#     </tr>
#     <tr>
#       <td>390</td>
#       <td>3.940200</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>3.514300</td>
#     </tr>
#     <tr>
#       <td>410</td>
#       <td>3.628600</td>
#     </tr>
#     <tr>
#       <td>420</td>
#       <td>3.980500</td>
#     </tr>
#     <tr>
#       <td>430</td>
#       <td>4.162000</td>
#     </tr>
#     <tr>
#       <td>440</td>
#       <td>3.695200</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>3.941200</td>
#     </tr>
#     <tr>
#       <td>460</td>
#       <td>3.986900</td>
#     </tr>
#     <tr>
#       <td>470</td>
#       <td>3.893600</td>
#     </tr>
#     <tr>
#       <td>480</td>
#       <td>3.814200</td>
#     </tr>
#     <tr>
#       <td>490</td>
#       <td>3.939400</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>3.821900</td>
#     </tr>
#     <tr>
#       <td>510</td>
#       <td>3.561300</td>
#     </tr>
#     <tr>
#       <td>520</td>
#       <td>3.521700</td>
#     </tr>
#     <tr>
#       <td>530</td>
#       <td>3.553000</td>
#     </tr>
#     <tr>
#       <td>540</td>
#       <td>3.452800</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>3.655100</td>
#     </tr>
#     <tr>
#       <td>560</td>
#       <td>3.708900</td>
#     </tr>
#     <tr>
#       <td>570</td>
#       <td>4.129000</td>
#     </tr>
#     <tr>
#       <td>580</td>
#       <td>3.727400</td>
#     </tr>
#     <tr>
#       <td>590</td>
#       <td>3.479700</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>3.744800</td>
#     </tr>
#     <tr>
#       <td>610</td>
#       <td>3.324000</td>
#     </tr>
#     <tr>
#       <td>620</td>
#       <td>3.535000</td>
#     </tr>
#     <tr>
#       <td>630</td>
#       <td>2.577600</td>
#     </tr>
#     <tr>
#       <td>640</td>
#       <td>2.998600</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>3.057400</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
trainer.evaluate()
